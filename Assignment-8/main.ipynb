# %% [markdown]
# Practical 8 : Apply WordNet-based Word Sense Disambiguation to improve meaning interpretation in
# ambiguous sentences.

# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.wsd import lesk
from nltk.tokenize import word_tokenize

sentence = "I went to the bank to deposit money."

words = word_tokenize(sentence)

sense = lesk(words, "bank")

print("Sentence:", sentence)
print("Disambiguated Sense:", sense)
print("Definition:", sense.definition())
# Out:
# Sentence: I went to the bank to deposit money.
# Disambiguated Sense: Synset('depository_financial_institution.n.01')
# Definition: a financial institution that accepts deposits and channels the money into lending activities

# %%
sentence = "The fisherman sat on the bank of the river."

words = word_tokenize(sentence)

sense = lesk(words, "bank")

print("Sentence:", sentence)
print("Sense:", sense)
print("Definition:", sense.definition())
# Out:
# Sentence: The fisherman sat on the bank of the river.
# Sense: Synset('bank.n.01')
# Definition: sloping land (especially the slope beside a body of water)

# %%
from nltk.corpus import wordnet
from nltk.wsd import lesk
from nltk.tokenize import word_tokenize

sentence = "The crane is flying over the lake."

words = word_tokenize(sentence)

for word in words:
    sense = lesk(words, word)
    
    if sense:
        print("Word:", word)
        print("Meaning:", sense.definition())
        print()
# Out:
# Word: crane
# Meaning: a small constellation in the southern hemisphere near Phoenix
#
# Word: is
# Meaning: have the quality of being; (copula, used with an adjective or a predicate noun)
#
# Word: flying
# Meaning: travel through the air; be airborne
#
# Word: over
# Meaning: over the entire area
#
# Word: lake
# Meaning: a body of (usually fresh) water surrounded by land
