# %% [markdown]
# 6. Develop a Machine Translation system to translate public information content between English
# and any Indian language.

# %%
# !pip install transformers sentencepiece
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 45.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 5.4 MB/s  0:00:00
# ...

# %%
from transformers import MarianMTModel, MarianTokenizer

model_name = "Helsinki-NLP/opus-mt-en-hi"

tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: aaab3452-b997-4f39-a98e-7639253b04d6)')' thrown while requesting HEAD https://huggingface.co/Helsinki-NLP/opus-mt-en-hi/resolve/main/tokenizer_config.json
# Retrying in 1s [Retry 1/5].
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# c:\Users\MANSI\anaconda3\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
english_text = [
    "The government has announced new health guidelines.",
    "Please wear a mask in public places.",
    "The train will arrive at the station at 6 PM."
]

# %%
def translate(texts):
    inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True)
    translated = model.generate(**inputs)
    return [tokenizer.decode(t, skip_special_tokens=True) for t in translated]

# %%
hindi_translation = translate(english_text)

for en, hi in zip(english_text, hindi_translation):
    print("English:", en)
    print("Hindi  :", hi)
    print()
# Out:
# English: The government has announced new health guidelines.
# Hindi  : सरकार ने नए स्वास्थ्य निर्देश घोषित किए हैं ।
#
# English: Please wear a mask in public places.
# Hindi  : सार्वजनिक स्थानों में मास्क पहनो.
#
# English: The train will arrive at the station at 6 PM.
# Hindi  : ट्रेन 6 प्रधानमंत्री पर स्टेशन पर पहुँच जाएगी.
