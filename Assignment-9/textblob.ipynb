# %%
# !pip install textblob deep-translator
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting textblob
#   Using cached textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting deep-translator
#   Using cached deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Collecting nltk>=3.9 (from textblob)
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting beautifulsoup4<5.0.0,>=4.9.1 (from deep-translator)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from deep-translator) (2.32.5)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator)
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.15.0)
# Requirement already satisfied: click in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk>=3.9->textblob) (2026.2.28)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2026.2.25)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Using cached textblob-0.20.0-py3-none-any.whl (624 kB)
# Using cached deep_translator-1.11.4-py3-none-any.whl (42 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, nltk, beautifulsoup4, textblob, deep-translator
# Successfully installed beautifulsoup4-4.14.3 deep-translator-1.11.4 nltk-3.9.4 soupsieve-2.8.3 textblob-0.20.0
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt')
from textblob import TextBlob
from deep_translator import GoogleTranslator
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
sentences = [
    "यह फिल्म बहुत अच्छी है",
    "मुझे यह खाना बिल्कुल पसंद नहीं आया"

]

# %%
for sentence in sentences:
    #translate to English
    translated = GoogleTranslator(source='auto', target='en').translate(sentence)

    blob = TextBlob(translated)
    polarity = blob.sentiment.polarity

    if polarity > 0:
        sentiment = "Positive"
    elif polarity == 0:
        sentiment = "Neutral"
    else:
        sentiment = "Negative"

    print(f"Original: {sentence}")
    print(f"Translated: {translated}")
    print(f"Sentiment: {sentiment} (Polarity: {polarity})")
    print("---")
# Out:
# Original: यह फिल्म बहुत अच्छी है
# Translated: this movie is very good
# Sentiment: Positive (Polarity: 0.9099999999999999)
# ---
# Original: मुझे यह खाना बिल्कुल पसंद नहीं आया
# Translated: I didn't like this food at all
# Sentiment: Neutral (Polarity: 0.0)
# ---
